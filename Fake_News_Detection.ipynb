# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalpesh-Nandedkar/CodeClauseInternship_Fake-News-Detection/blob/main/Fake_News_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from wordcloud import WordCloud
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ##Datasets Loading

# %%
true_df = pd.read_csv('/content/True.csv')
fake_df = pd.read_csv('/content/Fake.csv')

# %% [markdown]
# ## Viewing the Dataset

# %%
true_df.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %%
true_df.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
true_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
fake_df.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
fake_df.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
fake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %% [markdown]
# ##***Data Wrangling***

# %% [markdown]
# ###Creating a new column for target feature

# %%
true_df['target'] = 1
fake_df['target'] = 0

# %% [markdown]
# ###Merging the datasets

# %%
df = pd.concat([fake_df,true_df], axis = 0)

# %%
df.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %% [markdown]
# ## ***Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ##**Visualizing The Fake News**

# %%
# Visualizing the different subject present in the fake news dataframe
fake_subjectdf = fake_df['subject'].value_counts()
fake_subject_df = pd.DataFrame(fake_subjectdf)
fake_subject_df
# Out:
#                  subject
# News                9050
# politics            6841
# left-news           4459
# Government News     1570
# US_News              783
# Middle-east          778

# %%
# Plotting the bar chart for subject distribution in fake news dataframe
plt.figure(figsize=(8,6))
sns.countplot(x = 'subject', data = fake_df)
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %% [markdown]
# * We can see that  News & politics are having the most content while US_News & Middle-east having least content in Fake news dataset.

# %% [markdown]
# ###**WordCloud for Fake News**

# %%
text = ' '.join(fake_df['text'].tolist())
wordcloud = WordCloud(width = 1920 ,height = 1080).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# * From this we can say that the most Fake News is about Donald Trump.
# * Most Commonly used words in Fake News Dataset are People, Said, Ones, Trump, Will, etc...

# %% [markdown]
# ##**Visualizing The True News**

# %%
# Visualizing the different subject present in the True news dataframe
true_subjectdf = true_df['subject'].value_counts()
true_subject_df = pd.DataFrame(true_subjectdf)
true_subject_df
# Out:
#               subject
# politicsNews    11272
# worldnews       10145

# %%
# Plotting the bar chart for subject distribution in fake news dataframe
plt.figure(figsize=(8,6))
sns.countplot(x = 'subject', data = true_df)
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %% [markdown]
# * The True News Dataset has only two categories present i.e. Politics News & World News. Having Politics News the most.

# %% [markdown]
# ###**WordCloud for True News**

# %%
text = ' '.join(true_df['text'].tolist())
wordcloud = WordCloud(width = 1920 ,height = 1080).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# * The Most True News also have Donald Trump name the most.
# *  But in True News the name of states or country are present i.e. it shows the origin or relatable about the news.

# %% [markdown]
# ### **Category Distribution in each Year**

# %%
# Extracting the year
df['year'] = df['date'].str.split(",").str[1]
# Dropping NaN values from the data that may be produced by extracting the year above
df = df.dropna()
# Converting year from str to int
df.year = df.year.astype(int)

counts_year = df.groupby([pd.to_datetime(df['date']).dt.year, 'target']).size().reset_index(name='counts')

# Create a bar plot
sns.barplot(x="date", y='counts', hue='target', data=counts_year)
plt.legend(loc='upper left')
plt.title("Count of each Category in each year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# * 1 - Labelling as True News
#
#   0 - Labelling as Fake News
# * In Year 2015 there are no true news, While 2017 has the most True News

# %% [markdown]
# ##**Count of Each Subject in Each Year**

# %%
counts_subject_year = df.groupby([pd.to_datetime(df['date']).dt.year, 'subject']).size().reset_index(name='counts')
# Create a bar plot
ax = sns.barplot(x="date", y='counts', hue='subject', data=counts_subject_year)
ax.legend(loc='upper left')
plt.title("Count of each subject in each year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# * From the plot, we can see that the highest count is for worldNews in 2017, with a count of approximately 10,000.
# * The lowest count is for Middle-East and US_News in 2016, 2017 with a count of approximately 500.
# * The counts for Government News and left_news increased from 2015 to 2016 and slightly increased in 2017.

# %% [markdown]
# ##**Data Cleaning**

# %%
df.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'target', 'year'], dtype='object')

# %%
df = df.drop(['title','subject','date','year'], axis = 1)

# %% [markdown]
# ###Random Shuffling the dataframe

# %%
df = df.sample(frac = 1)

# %%
df.head(10)
# Out:
#                                                     text  target
# 3547   WELLESLEY, Mass. (Reuters) - Hillary Clinton a...       1
# 4457   MOSCOW (Reuters) - Russian foreign minister Se...       1
# 16674  KUALA LUMPUR (Reuters) - Malaysian Prime Minis...       1
# 14249  BAGHDAD (Reuters) - Iraqi Prime Minister Haide...       1
# 1884   Rep. Adam Schiff, the ranking Democrat on the ...       0
# 23421   21st Century Wire says The mainstream media c...       0
# 16106  This is so sad and such a lesson for the world...       0
# 7474   On Wednesday morning, Republican front runner ...       0
# 13010  19 year old native British man, Michael Sanfor...       0
# 13178  Thank you Lou Dobbs! He s been dead on this en...       0

# %%
df.reset_index(inplace=True)
df.drop(["index"], axis = 1, inplace = True)
df.head(10)
# Out:
#                                                 text  target
# 0  WELLESLEY, Mass. (Reuters) - Hillary Clinton a...       1
# 1  MOSCOW (Reuters) - Russian foreign minister Se...       1
# 2  KUALA LUMPUR (Reuters) - Malaysian Prime Minis...       1
# 3  BAGHDAD (Reuters) - Iraqi Prime Minister Haide...       1
# 4  Rep. Adam Schiff, the ranking Democrat on the ...       0
# 5   21st Century Wire says The mainstream media c...       0
# 6  This is so sad and such a lesson for the world...       0
# 7  On Wednesday morning, Republican front runner ...       0
# 8  19 year old native British man, Michael Sanfor...       0
# 9  Thank you Lou Dobbs! He s been dead on this en...       0

# %% [markdown]
# ###Creating a function to process the texts

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df["text"] = df["text"].apply(wordopt)

# %% [markdown]
# ###Defining dependent and independent variables

# %%
X = df["text"]
Y = df["target"]

# %% [markdown]
# ###Data Splitting

# %%
# performing train test split
X_train,x_test,Y_train,y_test = train_test_split(X,Y, test_size = 0.25)

# %% [markdown]
# ###Using TfidfVectorizer to convert Text To Vectors

# %%
#importing TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# Implementing TfidfVectorizer
vectorization = TfidfVectorizer()
analyze = vectorization.build_analyzer()
xv_train = vectorization.fit_transform(X_train)
xv_test = vectorization.transform(x_test)
print(xv_train.shape)
print(xv_test.shape)
# Out:
# (33639, 95050)
# (11214, 95050)

# %% [markdown]
# ##**ML Model Implementation**

# %% [markdown]
# ## **Model selection**
# ##1. Logistic Regression
# ##2. Decision Tree Classification
# ##3. Gradient Boosting Classifier
# ##4. Random Forest Classifier

# %% [markdown]
# # **ML Model - 1 - LOGISTIC REGRESSION**
